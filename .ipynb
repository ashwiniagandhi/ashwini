# %% [markdown]
# # Numpy

# %%
my_list=[1,5,6]
my_list

# %%
import numpy as np
arr=np.array(my_list)
arr

# %%
my_mat=[[1,2,3],[4,5,6]]
a=np.array(my_mat)
a

# %%
my_mat=[[1,2,3],[4,5,6],[6,8,7]]
b=np.array(my_mat)
b

# %%
my_mat=[[1,2],[4,5]]

# %%
np.arange(0,10)

# %%
np.arange(0,10,2)

# %%
np.zeros(3)

# %%
np.zeros((5,5))

# %%
np.zeros((2,3))

# %%
np.zeros(4)

# %%
np.zeros((3,4))

# %%
np.linspace(0,5,10)

# %%
np.linspace(0,5,100)
