# %%
import pandas as pd
import seaborn as sb
from pylab import rcParams
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rcParams['figure.figsize']=5,4
sb.set_style('whitegrid')

# %%
df=pd.read_csv("C:\\Users\\SAGAR\\Documents\\ashwini\\pandas\\linear_regression\\MELBOURNE_HOUSE_PRICES_LESS.csv")
df
# Out:
#                   Suburb                 Address  Rooms Type      Price  \
# 0             Abbotsford           49 Lithgow St      3    h  1490000.0
# 1             Abbotsford           59A Turner St      3    h  1490000.0
# 2             Abbotsford           119B Yarra St      3    h  1420000.0
# 3             Aberfeldie              68 Vida St      3    h  1515000.0
# 4           Airport West        92 Clydesdale Rd      2    h   670000.0
# 5           Airport West            4/32 Earl St      2    t   530000.0
# 6           Airport West          3/74 Hawker St      2    u   540000.0
# 7           Airport West       1/26 Highridge Cr      3    h   715000.0
# 8              Albanvale           1 Jackson Cct      6    h        NaN
# 9            Albert Park             18 Mills St      3    h  1925000.0
# 10                Albion      3/15 Drummartin St      3    u   515000.0
# 11                Albion          3A Kororoit St      4    h   717000.0
# ...

# %%
inputs_n=df.drop(['Suburb','Address','Type','Method','SellerG','Date','Regionname','CouncilArea'],axis='columns')
inputs_n
# Out:
#        Rooms      Price  Postcode  Propertycount  Distance
# 0          3  1490000.0      3067           4019       3.0
# 1          3  1490000.0      3067           4019       3.0
# 2          3  1420000.0      3067           4019       3.0
# 3          3  1515000.0      3040           1543       7.5
# 4          2   670000.0      3042           3464      10.4
# 5          2   530000.0      3042           3464      10.4
# 6          2   540000.0      3042           3464      10.4
# 7          3   715000.0      3042           3464      10.4
# 8          6        NaN      3021           1899      14.0
# 9          3  1925000.0      3206           3280       3.0
# 10         3   515000.0      3020           2185      10.5
# 11         4   717000.0      3020           2185      10.5
# 12         2  1675000.0      3078           2211       5.7
# 13         4  2008000.0      3078           2211       5.7
# 14         2   860000.0      3018           5301      11.0
# ...

# %%
inputs_n.head()
# Out:
#    Rooms      Price  Postcode  Propertycount  Distance
# 0      3  1490000.0      3067           4019       3.0
# 1      3  1490000.0      3067           4019       3.0
# 2      3  1420000.0      3067           4019       3.0
# 3      3  1515000.0      3040           1543       7.5
# 4      2   670000.0      3042           3464      10.4

# %%
sb.boxplot(x='Rooms',y='Price',data=df)

# %%
sb.paiplot(df,hue='Rooms',palette='his')
# Out:
# Populating the interactive namespace from numpy and matplotlib
