# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

# %%
x=np.linspace(0,5,11)
y=x**2#square
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'r--')
plt.show()

# %%
plt.plot(x,y,'r_')
plt.show()

# %%
plt.plot(x,y,'r-')
plt.show()

# %%
plt.plot(x,y)
plt.xlabel('Xlabel')
plt.ylabel('Ylabel')
plt.title('graph')
# Out:
# Text(0.5, 1.0, 'graph')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(y,x,'b')#blue

# %%
fig=plt.figure()
fig

# %%
fig=plt.figure()

axes=fig.add_axes([0.1,0.1,0.8,0.8])

# %%
fig=plt.figure()

axes=fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)

# %%
fig=plt.figure()

axes=fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_xlabel('X label')
axes.set_ylabel('Y label')
axes.set_title('set title')
# Out:
# Text(0.5, 1.0, 'set title')

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes1=fig.add_axes([0.2,0.5,0.4,0.3])

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes1=fig.add_axes([0.2,0.15,0.4,0.3])

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.8,0.5,0.4,0.3])

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.8,0.5,0.4,0.3])
axes2.plot(y,x)
axes1.plot(x,y)

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.8,0.5,0.4,0.3])

axes1.plot(x,y)
axes2.plot(y,x)

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.8,0.5,0.4,0.3])
axes1.set_title('lagere')
axes1.plot(x,y)
axes2.plot(y,x)
axes2.set_title('smaller')
# Out:
# Text(0.5, 1.0, 'smaller')

# %%
fig,axes=plt.subplots(nrows=3,ncols=2)
axes.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-c5f114b456a3> in <module>
#       1 fig,axes=plt.subplots(nrows=3,ncols=2)
# ----> 2 axes.plot(x,y)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)

# %%
fig,axes=plt.subplots(nrows=3,ncols=2)
plt.tight_layout()
